# %% [markdown]
# # Part III: Data Visualization
#
# In Part I, data is collected using the API, and cleaned in Part II. In Part III, visualization is performed to detect any possible outliers, anomalies, and build intuition around the data before performing machine learning modelling in Part IV.
#
# In this notebook, the following has been done:
# 1. Import pandas and data vizualization libraries
# 2. Visualize the taxi availability over the month
# 3. Visualize the taxi availability over the 24 hours in a day
# 4. Visualize the taxi availability by day of the week
#
#
# ### Step 1: Import the following libraries
# - pandas
# - matplotlib.pyplot as plt
# - seaborn as sns

# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2: Read the CSV from Part II
# Read the CSV from Part II using pandas.
#
# Things to take note of:
# 1. make sure 'time' is index
# 2. parse the datetime in 'time' so that it's a proper DateTime object

# %%
# Step 2: Read CSV as DateTime and make sure the dates are parsed
data = pd.read_csv('Ordered_DataFrame.csv', parse_dates=True)
data['time'] = pd.to_datetime(data['time'])
data = data.set_index('time')
display(data)
# Out:
#                      Unnamed: 0  properties.taxi_count  day_of_week  minute  \
# time
# 2019-01-01 00:00:00           0                   5887            1       0
# 2019-01-01 00:05:00           1                   4001            1       5
# 2019-01-01 00:10:00           2                   5981            1      10
# 2019-01-01 00:15:00           3                   5461            1      15
# 2019-01-01 00:20:00           4                   5003            1      20
# ...                         ...                    ...          ...     ...
# 2019-01-30 23:40:00        8636                   5782            5      40
# 2019-01-30 23:45:00        8637                   5843            5      45
# 2019-01-30 23:50:00        8638                   5825            5      50
# 2019-01-30 23:55:00        8639                   5783            5      55
# 2019-01-31 00:00:00        8640                   5848            5       0
#
# ...

# %%
data = data.iloc[: , 1:]
data
# Out:
#                      properties.taxi_count  day_of_week  minute  hour  \
# time
# 2019-01-01 00:00:00                   5887            1       0     0
# 2019-01-01 00:05:00                   4001            1       5     0
# 2019-01-01 00:10:00                   5981            1      10     0
# 2019-01-01 00:15:00                   5461            1      15     0
# 2019-01-01 00:20:00                   5003            1      20     0
# ...                                    ...          ...     ...   ...
# 2019-01-30 23:40:00                   5782            5      40    23
# 2019-01-30 23:45:00                   5843            5      45    23
# 2019-01-30 23:50:00                   5825            5      50    23
# 2019-01-30 23:55:00                   5783            5      55    23
# 2019-01-31 00:00:00                   5848            5       0     0
#
#                      sector_1  sector_2  sector_3  sector_4  sector_5  \
# time
# ...

# %% [markdown]
# ### Step 3: Plot 'properties.taxi_count'
# Onwards to the first plot!

# %%
# Step 3: Plot properties.taxi_count vs time
plt.figure(figsize = (20, 8))
plt.plot(data.index.values, data['properties.taxi_count'])
plt.title("'properties.taxi_count' vs. Time", fontsize = 14, fontweight = "bold")
plt.xlabel("Time")
plt.ylabel("properties.taxi_count")
plt.show()

# %% [markdown]
# ### Step 4: Investigate the odd datapoints
# The visualization suggests that there are 0 taxis available in Singapore on certain days. This simply cannot be.
#
# Before proceeding further with visualization, let's either remove or fix this problem.
#
# Check the parts in the DataFrame where "properties.taxi_count" == 0. Slice the DataFrame based on the column values.

# %%
# Step 4: Get the slice where there is no taxi counts
no_taxi = data.loc[data['properties.taxi_count'] == 0]
no_taxi
# Out:
#                      properties.taxi_count  day_of_week  minute  hour  \
# time
# 2019-01-08 00:10:00                      0            2      10     0
# 2019-01-12 00:10:00                      0            2      10     0
# 2019-01-12 16:55:00                      0            2      55    16
# 2019-01-17 11:25:00                      0            3      25    11
# 2019-01-17 11:30:00                      0            3      30    11
# 2019-01-17 11:35:00                      0            3      35    11
# 2019-01-17 11:40:00                      0            3      40    11
# 2019-01-17 11:45:00                      0            3      45    11
# 2019-01-17 11:50:00                      0            3      50    11
# 2019-01-17 11:55:00                      0            3      55    11
# 2019-01-17 12:00:00                      0            3       0    12
# 2019-01-17 12:05:00                      0            3       5    12
# ...

# %% [markdown]
# ### Step 5: Remove those erroneous rows
# Looks like there was some downtime on those days, since all of the columns contain 0. As such, remove them. This is where visualization helps in identifying anomalous parts of the dataset.

# %%
# Step 5: Remove rows where properties.taxi_count is 0
has_taxi = data[data['properties.taxi_count'] != 0]
display(has_taxi)
# Out:
#                      properties.taxi_count  day_of_week  minute  hour  \
# time
# 2019-01-01 00:00:00                   5887            1       0     0
# 2019-01-01 00:05:00                   4001            1       5     0
# 2019-01-01 00:10:00                   5981            1      10     0
# 2019-01-01 00:15:00                   5461            1      15     0
# 2019-01-01 00:20:00                   5003            1      20     0
# ...                                    ...          ...     ...   ...
# 2019-01-30 23:40:00                   5782            5      40    23
# 2019-01-30 23:45:00                   5843            5      45    23
# 2019-01-30 23:50:00                   5825            5      50    23
# 2019-01-30 23:55:00                   5783            5      55    23
# 2019-01-31 00:00:00                   5848            5       0     0
#
#                      sector_1  sector_2  sector_3  sector_4  sector_5  \
# time
# ...

# %% [markdown]
# ### Step 6: Resample the DataFrame by day
# The current plot seems very chaotic, and it's going to be hard to intuit anything from it, e.g., whether the data is cyclical, etc.
#
# As such, let's resample the DataFrame and take the median! This is so that intra-day variation can be reduced and focus on the median to identify if there is any possible pattern.
#
# In a median resample, the DataFrame index now considers only the <strong>Day</strong>. Notice how the hours have disappeared, leaving only the date.

# %%
# Step 6: Resample DataFrame by day, and take the day's median value
has_taxi_daily = has_taxi.resample('D').median()
has_taxi_daily
# Out:
#             properties.taxi_count  day_of_week  minute  hour  sector_1  \
# time
# 2019-01-01                 4156.0          1.0    27.5  11.5     202.5
# 2019-01-02                 4841.5          1.0    27.5  11.5     185.0
# 2019-01-03                 4897.0          1.0    27.5  11.5     188.5
# 2019-01-04                 4598.5          1.0    27.5  11.5     173.0
# 2019-01-05                 4454.0          1.0    27.5  11.5     182.0
# 2019-01-06                 4071.5          1.0    27.5  11.5     173.0
# 2019-01-07                 4504.5          2.0    27.5  11.5     176.0
# 2019-01-08                 4657.0          2.0    30.0  12.0     171.0
# 2019-01-09                 4662.0          2.0    27.5  11.5     166.5
# 2019-01-10                 4746.5          2.0    27.5  11.5     176.0
# 2019-01-11                 4242.5          2.0    27.5  11.5     155.0
# 2019-01-12                 3824.5          2.0    27.5  11.5     151.5
# ...

# %% [markdown]
# ### Step 7: Plot 'properties.taxi_count' from the resampled DataFrame over original plot
# After resampled the DataFrame by day, it's time to plot it to see the effects of analysis.

# %%
# Step 7: Plot resampled DataFrame over original plot
labels = ["Intraday", "Daily"]

plt.figure(figsize = (20, 8))
plt.plot(data.index.values, data['properties.taxi_count'])
plt.plot(has_taxi_daily.index.values, has_taxi_daily['properties.taxi_count'])
plt.title("'properties.taxi_count' vs. Time", fontsize = 14, fontweight = "bold")
plt.xlabel("Time")
plt.ylabel("properties.taxi_count")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# %% [markdown]
# Once resampled, there is less intraday variation since only the median of the day is taken. More importantly, the rough cyclic nature of the available taxis throughout the month is visible.
#
# ### Do the same analysis on sectors 1-9
# Do the same analysis on sectors 1-9 and see how the resamples vary with the taxi availability in different parts of Singapore.

# %%
# Do the same analysis for sectors 1-9
# sector 1
labels = ["Intraday", "Daily"]

plt.figure(figsize = (20, 8))
plt.plot(data.index.values, data['sector_1'])
plt.plot(has_taxi_daily.index.values, has_taxi_daily['sector_1'])
plt.title("'properties.taxi_count' vs. Sector 1", fontsize = 14, fontweight = "bold")
plt.xlabel("Time")
plt.ylabel("Sector 1")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# sector 2
labels = ["Intraday", "Daily"]

plt.figure(figsize = (20, 8))
plt.plot(data.index.values, data['sector_2'])
plt.plot(has_taxi_daily.index.values, has_taxi_daily['sector_2'])
plt.title("'properties.taxi_count' vs. Sector 2", fontsize = 14, fontweight = "bold")
plt.xlabel("Time")
plt.ylabel("Sector 2")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# sector 3
labels = ["Intraday", "Daily"]

plt.figure(figsize = (20, 8))
plt.plot(data.index.values, data['sector_3'])
plt.plot(has_taxi_daily.index.values, has_taxi_daily['sector_3'])
plt.title("'properties.taxi_count' vs. Sector 3", fontsize = 14, fontweight = "bold")
plt.xlabel("Time")
plt.ylabel("Sector 3")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# sector 4
labels = ["Intraday", "Daily"]

plt.figure(figsize = (20, 8))
plt.plot(data.index.values, data['sector_4'])
plt.plot(has_taxi_daily.index.values, has_taxi_daily['sector_4'])
plt.title("'properties.taxi_count' vs. Sector 4", fontsize = 14, fontweight = "bold")
plt.xlabel("Time")
plt.ylabel("Sector 4")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# sector 5
labels = ["Intraday", "Daily"]

plt.figure(figsize = (20, 8))
plt.plot(data.index.values, data['sector_5'])
plt.plot(has_taxi_daily.index.values, has_taxi_daily['sector_5'])
plt.title("'properties.taxi_count' vs. Sector 5", fontsize = 14, fontweight = "bold")
plt.xlabel("Time")
plt.ylabel("Sector 5")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# sector 6
labels = ["Intraday", "Daily"]

plt.figure(figsize = (20, 8))
plt.plot(data.index.values, data['sector_6'])
plt.plot(has_taxi_daily.index.values, has_taxi_daily['sector_6'])
plt.title("'properties.taxi_count' vs. Sector 6", fontsize = 14, fontweight = "bold")
plt.xlabel("Time")
plt.ylabel("Sector 6")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# sector 7
labels = ["Intraday", "Daily"]

plt.figure(figsize = (20, 8))
plt.plot(data.index.values, data['sector_7'])
plt.plot(has_taxi_daily.index.values, has_taxi_daily['sector_7'])
plt.title("'properties.taxi_count' vs. Sector 7", fontsize = 14, fontweight = "bold")
plt.xlabel("Time")
plt.ylabel("Sector 7")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# sector 8
labels = ["Intraday", "Daily"]

plt.figure(figsize = (20, 8))
plt.plot(data.index.values, data['sector_8'])
plt.plot(has_taxi_daily.index.values, has_taxi_daily['sector_8'])
plt.title("'properties.taxi_count' vs. Sector 8", fontsize = 14, fontweight = "bold")
plt.xlabel("Time")
plt.ylabel("Sector 8")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# sector 9
labels = ["Intraday", "Daily"]

plt.figure(figsize = (20, 8))
plt.plot(data.index.values, data['sector_9'])
plt.plot(has_taxi_daily.index.values, has_taxi_daily['sector_9'])
plt.title("'properties.taxi_count' vs. Sector 9", fontsize = 14, fontweight = "bold")
plt.xlabel("Time")
plt.ylabel("Sector 9")
plt.legend(labels = labels, fontsize = "large")
plt.show()

# %% [markdown]
# ### Step 10: Get the hourly average of taxi availability
# Get the hourly average data of the DataFrame. This means averaging all of the taxi availability for the hours of the day, across all days.
#
# Compared to what is done in Step 9 where it was a resampling, what is done here is to group the 'properties.taxi_count' by the hour and followed by the averaging.

# %%
# Step 10: Get the DataFrame containing the hourly average
has_taxi_hourly = has_taxi.groupby(has_taxi.index.hour).mean()
has_taxi_hourly
# Out:
#       properties.taxi_count  day_of_week     minute  hour    sector_1  \
# time
# 0               4940.000000     2.810585  27.520891   0.0  196.239554
# 1               4751.481894     2.796657  27.520891   1.0  199.618384
# 2               4591.649860     2.789916  27.324930   2.0  190.983193
# 3               4133.565826     2.789916  27.689076   3.0  192.809524
# 4               4010.252778     2.800000  27.500000   4.0  200.222222
# 5               3808.086111     2.800000  27.500000   5.0  186.730556
# 6               3447.136111     2.800000  27.500000   6.0  151.002778
# 7               3711.058333     2.800000  27.500000   7.0  138.788889
# 8               3441.280556     2.800000  27.500000   8.0  117.716667
# 9               3985.377778     2.800000  27.500000   9.0  111.280556
# 10              4202.116667     2.800000  27.500000  10.0  104.136111
# 11              4171.773371     2.796034  27.252125  11.0  107.351275
# ...

# %% [markdown]
# ### Step 11: Plot the hourly average of 'properties.taxi_count' using barplot
# Time to plot the the averages to see if there's a pattern.

# %%
# Step 11: Plot the hourly average of 'properties.taxi_count'
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_hourly.index.values, height = has_taxi_hourly['properties.taxi_count'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Hourly Average of 'properties.taxi_count'", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Hour", fontsize = 13)
plt.ylabel("properties.taxi_count", fontsize = 13)
plt.show()

# %% [markdown]
# ### Repeat Step 11 for sectors 1-9
# Try to do the same for sectors 1-9 and see if there are any differences in the patterns.

# %%
# Additional plots for sectors 1-9
# sector 1
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_hourly.index.values, height = has_taxi_hourly['sector_1'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Hourly Average of Sector 1", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Hour", fontsize = 13)
plt.ylabel("Sector 1", fontsize = 13)
plt.show()

# sector 2
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_hourly.index.values, height = has_taxi_hourly['sector_2'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Hourly Average of Sector 2", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Hour", fontsize = 13)
plt.ylabel("Sector 2", fontsize = 13)
plt.show()

# sector 3
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_hourly.index.values, height = has_taxi_hourly['sector_3'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Hourly Average of Sector 3", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Hour", fontsize = 13)
plt.ylabel("Sector 3", fontsize = 13)
plt.show()

# sector 4
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_hourly.index.values, height = has_taxi_hourly['sector_4'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Hourly Average of Sector 4", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Hour", fontsize = 13)
plt.ylabel("Sector 4", fontsize = 13)
plt.show()

# sector 5
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_hourly.index.values, height = has_taxi_hourly['sector_5'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Hourly Average of Sector 5", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Hour", fontsize = 13)
plt.ylabel("Sector 5", fontsize = 13)
plt.show()

# sector 6
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_hourly.index.values, height = has_taxi_hourly['sector_6'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Hourly Average of Sector 6", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Hour", fontsize = 13)
plt.ylabel("Sector 6", fontsize = 13)
plt.show()

# sector 7
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_hourly.index.values, height = has_taxi_hourly['sector_7'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Hourly Average of Sector 7", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Hour", fontsize = 13)
plt.ylabel("Sector 7", fontsize = 13)
plt.show()

# sector 8
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_hourly.index.values, height = has_taxi_hourly['sector_8'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Hourly Average of Sector 8", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Hour", fontsize = 13)
plt.ylabel("Sector 8", fontsize = 13)
plt.show()

# sector 9
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_hourly.index.values, height = has_taxi_hourly['sector_9'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Hourly Average of Sector 9", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Hour", fontsize = 13)
plt.ylabel("Sector 9", fontsize = 13)
plt.show()

# %% [markdown]
# ### Step 12: Get the day of week average DataFrame
# At first, the hourly average of the data is obtained. Next, get the day of week average, i.e. the averages of Monday, Tuesday, ..., Sunday.

# %%
# Step 12: Get the day of week average
has_taxi_day_of_week = has_taxi.groupby(has_taxi.index.dayofweek).mean()
has_taxi_day_of_week
# Out:
#       properties.taxi_count  day_of_week     minute       hour    sector_1  \
# time
# 0               4236.539062     3.500000  27.500000  11.500000  157.656250
# 1               4361.679047     2.992292  27.480729  11.491240  170.686755
# 2               4476.230716     2.999305  27.480890  11.496873  162.587908
# 3               4566.809311     2.481647  27.412713  11.511191  167.230976
# 4               4144.194590     2.494764  27.495637  11.498255  146.516579
# 5               3984.288077     2.500435  27.467363  11.502176  154.031332
# 6               3717.925282     2.498697  27.489140  11.508254  148.900956
#
#         sector_2   sector_3    sector_4     sector_5    sector_6  sector_7  \
# time
# 0     894.095486  76.335938  460.129340  1921.282118  701.588542  0.513889
# 1     944.627891  80.146461  474.902593  1965.480729  699.955851  0.384022
# 2     929.720639  80.020848  469.258513  2088.592773  720.619875  0.411397
# ...

# %% [markdown]
# ### Step 13: Plot the day of week average for 'properties.taxi_count', and sectors 1-9
# Plot the day of week average for 'properties.taxi_count' and the nine sectors.

# %%
# Step 13: Plot day of week average for properties.taxi_count
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_day_of_week.index.values, height = has_taxi_day_of_week['properties.taxi_count'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Day of Week Average of 'properties.taxi_count'", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Day of Week", fontsize = 13)
plt.ylabel("properties.taxi_count", fontsize = 13)
plt.show()

# Plot day of week average for sectors 1-9
# sector 1
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_day_of_week.index.values, height = has_taxi_day_of_week['sector_1'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Day of Week Average of Sector 1", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Day of Week", fontsize = 13)
plt.ylabel("Sector 1", fontsize = 13)
plt.show()

# sector 2
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_day_of_week.index.values, height = has_taxi_day_of_week['sector_2'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Day of Week Average of Sector 2", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Day of Week", fontsize = 13)
plt.ylabel("Sector 2", fontsize = 13)
plt.show()

# sector 3
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_day_of_week.index.values, height = has_taxi_day_of_week['sector_3'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Day of Week Average of Sector 3", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Day of Week", fontsize = 13)
plt.ylabel("Sector 3", fontsize = 13)
plt.show()

# sector 4
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_day_of_week.index.values, height = has_taxi_day_of_week['sector_4'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Day of Week Average of Sector 4", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Day of Week", fontsize = 13)
plt.ylabel("Sector 4", fontsize = 13)
plt.show()

# sector 5
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_day_of_week.index.values, height = has_taxi_day_of_week['sector_5'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Day of Week Average of Sector 5", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Day of Week", fontsize = 13)
plt.ylabel("Sector 5", fontsize = 13)
plt.show()

# sector 6
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_day_of_week.index.values, height = has_taxi_day_of_week['sector_6'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Day of Week Average of Sector 6", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Day of Week", fontsize = 13)
plt.ylabel("Sector 6", fontsize = 13)
plt.show()

# sector 7
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_day_of_week.index.values, height = has_taxi_day_of_week['sector_7'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Day of Week Average of Sector 7", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Day of Week", fontsize = 13)
plt.ylabel("Sector 7", fontsize = 13)
plt.show()

# sector 8
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_day_of_week.index.values, height = has_taxi_day_of_week['sector_8'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Day of Week Average of Sector 8", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Day of Week", fontsize = 13)
plt.ylabel("Sector 8", fontsize = 13)
plt.show()

# sector 9
plt.figure(figsize = (9, 6))
plt.bar(x = has_taxi_day_of_week.index.values, height = has_taxi_day_of_week['sector_9'], color = "midnightblue")
plt.xticks(fontsize = 13)
plt.yticks(fontsize = 13)
plt.title("Day of Week Average of Sector 9", fontsize = 16, fontweight = "bold")
plt.xlabel("Time by Day of Week", fontsize = 13)
plt.ylabel("Sector 9", fontsize = 13)
plt.show()

# %% [markdown]
# ### Step 14: Drop the columns that don't contain data
# Noticed that there are some sectors that do not contain any coordinates. These are sectors 7 and 9.
#
# Let's just drop these columns.

# %%
# Step 14: Remove the columns from the DataFrame
cleaned_has_taxi = has_taxi.drop(columns=['sector_7', 'sector_9'])
cleaned_has_taxi
# Out:
#                      properties.taxi_count  day_of_week  minute  hour  \
# time
# 2019-01-01 00:00:00                   5887            1       0     0
# 2019-01-01 00:05:00                   4001            1       5     0
# 2019-01-01 00:10:00                   5981            1      10     0
# 2019-01-01 00:15:00                   5461            1      15     0
# 2019-01-01 00:20:00                   5003            1      20     0
# ...                                    ...          ...     ...   ...
# 2019-01-30 23:40:00                   5782            5      40    23
# 2019-01-30 23:45:00                   5843            5      45    23
# 2019-01-30 23:50:00                   5825            5      50    23
# 2019-01-30 23:55:00                   5783            5      55    23
# 2019-01-31 00:00:00                   5848            5       0     0
#
#                      sector_1  sector_2  sector_3  sector_4  sector_5  \
# time
# ...

# %% [markdown]
# # Step 15: Export DataFrame as CSV
# In this Part, data is transformed and visualized to identify patterns and outliers. After successfully identified odd rows containing absolutely no available taxis, sectors in the dataset that wasn't useful, i.e. 0 at all times are removed.
#
# After done dropping the empty columns, export the cleaned DataFrame as a CSV for use in Part IV!

# %%
# Step 15: Export cleaned DataFrame as CSV
cleaned_has_taxi.to_csv ('Cleaned_DataFrame.csv')
